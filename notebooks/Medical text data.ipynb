# %% [markdown]
# <p style="background-color:purple; font-family:newtimeroman; color:#FFF9ED; font-size:200%; text-align:center; border-radius:20px; padding:20px;"><strong>Medical Text Dataset -Cancer Doc Sentiment Analysis and classification.</strong></p>

# %%
from IPython.display import display, Image
file_path = r'C:\Users\Vijay\Downloads\c1.jpg'
display(Image(filename=file_path, width=950, height=750))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 from IPython.display import display, Image
#       2 file_path = r'C:\Users\Vijay\Downloads\c1.jpg'
# ----> 3 display(Image(filename=file_path, width=950, height=750))
#
# File ~\anaconda3\Lib\site-packages\IPython\core\display.py:970, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#     968 self.unconfined = unconfined
#     969 self.alt = alt
# --> 970 super(Image, self).__init__(data=data, url=url, filename=filename,
#     971         metadata=metadata)
#     973 if self.width is None and self.metadata.get('width', {}):
#     974     self.width = metadata['width']
#
# File ~\anaconda3\Lib\site-packages\IPython\core\display.py:327, in DisplayObject.__init__(self, data, url, filename, metadata)
#     324 elif self.metadata is None:
#     325     self.metadata = {}
# --> 327 self.reload()
#     328 self._check_data()
#
# File ~\anaconda3\Lib\site-packages\IPython\core\display.py:1005, in Image.reload(self)
#    1003 """Reload the raw data from file or URL."""
#    1004 if self.embed:
# -> 1005     super(Image,self).reload()
#    1006     if self.retina:
#    1007         self._retina_shape()
#
# File ~\anaconda3\Lib\site-packages\IPython\core\display.py:353, in DisplayObject.reload(self)
#     351 if self.filename is not None:
#     352     encoding = None if "b" in self._read_flags else "utf-8"
# --> 353     with open(self.filename, self._read_flags, encoding=encoding) as f:
#     354         self.data = f.read()
#     355 elif self.url is not None:
#     356     # Deferred import
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Vijay\\Downloads\\c1.jpg'

# %%
import pandas as pd

# %% [markdown]
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:black; background-color:#dfa8e4; font-size: 16px; border-width: 2px; font-weight: bold;" data-toggle="popover"><span style="font-size: 20px;">AIM : </span>
#
# - The aim of the project is to use NLP and Deep learning techniques to automatically classify medical
# - documents related to cancer, leveraging a dataset of medical texts
# - This allows the system to adapt to evolving medical knowledge and practices.

# %% [markdown]
# ### The data is a collection of 7570 Rows and 3 column variables. Each row includes a written comment as well as additional customer information. Also each row corresponds to a customer review, and includes the variables:

# %% [markdown]
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:black; background-color:#dfa8e4; font-size: 16px; border-width: 2px; font-weight: bold;" data-toggle="popover"><span style="font-size: 20px;">Feature Information: </span>
#
# - **1** - 0 :colon cancer=2579, lung cancer=2180, thyroid cancer=2810
#
# - **2** - a:Text Data regarding Canser Health Canser Text Classification categoroial

# %% [markdown]
# <a id="2"></a>
# ## <p style="background-color:#B61151; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;"> LIBRARIES NEEDED IN THE STUDY<p>

# %%
#LIBRARIES NEEDED IN THE STUDY
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import sys
import tensorflow as tf
import keras.models
#from keras.models import Sequential
from keras.layers import Conv2D , MaxPool2D ,Flatten , Dense, Dropout
#from keras.utils import to_categorical
from tensorflow.keras.utils import to_categorical
from PIL import Image
from keras.models import Model, Sequential
from keras.layers import GlobalAveragePooling2D , BatchNormalization;
#from models import custom_convnet
from keras.layers import Embedding
from tensorflow.keras.layers import LSTM
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn.metrics import classification_report
from keras.layers import Bidirectional
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Embedding
from tensorflow.keras.optimizers import Adam
# Out:
# WARNING:tensorflow:From C:\Users\Vijay\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:black; background-color:#dfa8e4; font-size: 16px; border-width: 2px; font-weight: bold;" data-toggle="popover">
# <span style="font-size: 20px;">NLP</span></a>
#
# ###  In a project context, you could succinctly define NLP as "the branch of artificial intelligence (AI)focused on enabling computers to understand,interpret, and generate human language."

# %% [markdown]
# <a id="3"></a>
# ## <p style="background-color:#B61151; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;"> Loading and Reading Data <p>

# %%
pd.read_csv(r"D:\Medical.csv",encoding='latin-1')
# Out:
#       Unnamed: 0               0  \
# 0              0  Thyroid_Cancer
# 1              1  Thyroid_Cancer
# 2              2  Thyroid_Cancer
# 3              3  Thyroid_Cancer
# 4              4  Thyroid_Cancer
# ...          ...             ...
# 7565        7565    Colon_Cancer
# 7566        7566    Colon_Cancer
# 7567        7567    Colon_Cancer
# 7568        7568    Colon_Cancer
# 7569        7569    Colon_Cancer
#
#                                                       a
# 0     Thyroid surgery in  children in a single insti...
# 1     " The adopted strategy was the same as that us...
# 2     coronary arterybypass grafting thrombosis ï¬b...
# 3      Solitary plasmacytoma SP of the skull is an u...
# 4      This study aimed to investigate serum matrix ...
# ...                                                 ...
# 7565  we report the case of a 24yearold man who pres...
# 7566  among synchronous colorectal cancers scrcs rep...
# 7567  the heterogeneity of cancer cells is generally...
# 7568  "adipogenesis is the process through which mes...
# 7569  the periparturient period is one of the most c...
#
# [7570 rows x 3 columns]

# %%
med=pd.read_csv(r"D:\Medical.csv",encoding='latin-1')

# %% [markdown]
# ## <p style="background-color:#B61151; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">

# %%
# Plot the histogram using matplotlib
plt.hist(med['0'], bins='auto', color='skyblue', edgecolor='black')

plt.xlabel('0')
plt.ylabel('count')
plt.title('types of canser')

plt.show()

# %% [markdown]
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:black; background-color:#dfa8e4; font-size: 16px; border-width: 2px; font-weight: bold;" data-toggle="popover">
# <span style="font-size: 20px;">Data Analysis</span></a>

# %%
med.isnull().sum()>0
# Out:
# Unnamed: 0    False
# 0             False
# a             False
# dtype: bool

# %%
med=med.loc[:,['0','a']]

# %%
med
# Out:
#                    0                                                  a
# 0     Thyroid_Cancer  Thyroid surgery in  children in a single insti...
# 1     Thyroid_Cancer  " The adopted strategy was the same as that us...
# 2     Thyroid_Cancer  coronary arterybypass grafting thrombosis ï¬b...
# 3     Thyroid_Cancer   Solitary plasmacytoma SP of the skull is an u...
# 4     Thyroid_Cancer   This study aimed to investigate serum matrix ...
# ...              ...                                                ...
# 7565    Colon_Cancer  we report the case of a 24yearold man who pres...
# 7566    Colon_Cancer  among synchronous colorectal cancers scrcs rep...
# 7567    Colon_Cancer  the heterogeneity of cancer cells is generally...
# 7568    Colon_Cancer  "adipogenesis is the process through which mes...
# 7569    Colon_Cancer  the periparturient period is one of the most c...
#
# [7570 rows x 2 columns]

# %%
med=med.rename(columns={'0':'y','a':'x'})

# %%
med
# Out:
#                    y                                                  x
# 0     Thyroid_Cancer  Thyroid surgery in  children in a single insti...
# 1     Thyroid_Cancer  " The adopted strategy was the same as that us...
# 2     Thyroid_Cancer  coronary arterybypass grafting thrombosis ï¬b...
# 3     Thyroid_Cancer   Solitary plasmacytoma SP of the skull is an u...
# 4     Thyroid_Cancer   This study aimed to investigate serum matrix ...
# ...              ...                                                ...
# 7565    Colon_Cancer  we report the case of a 24yearold man who pres...
# 7566    Colon_Cancer  among synchronous colorectal cancers scrcs rep...
# 7567    Colon_Cancer  the heterogeneity of cancer cells is generally...
# 7568    Colon_Cancer  "adipogenesis is the process through which mes...
# 7569    Colon_Cancer  the periparturient period is one of the most c...
#
# [7570 rows x 2 columns]

# %%
med.y.value_counts()
# Out:
# Thyroid_Cancer    2810
# Colon_Cancer      2580
# Lung_Cancer       2180
# Name: y, dtype: int64

# %%
med.head()
# Out:
#                 y                                                  x
# 0  Thyroid_Cancer  Thyroid surgery in  children in a single insti...
# 1  Thyroid_Cancer  " The adopted strategy was the same as that us...
# 2  Thyroid_Cancer  coronary arterybypass grafting thrombosis ï¬b...
# 3  Thyroid_Cancer   Solitary plasmacytoma SP of the skull is an u...
# 4  Thyroid_Cancer   This study aimed to investigate serum matrix ...

# %%
med=med.replace({'Thyroid_Cancer':0,'Colon_Cancer':1,'Lung_Cancer':2})

# %%
med
# Out:
#       y                                                  x
# 0     0  Thyroid surgery in  children in a single insti...
# 1     0  " The adopted strategy was the same as that us...
# 2     0  coronary arterybypass grafting thrombosis ï¬b...
# 3     0   Solitary plasmacytoma SP of the skull is an u...
# 4     0   This study aimed to investigate serum matrix ...
# ...  ..                                                ...
# 7565  1  we report the case of a 24yearold man who pres...
# 7566  1  among synchronous colorectal cancers scrcs rep...
# 7567  1  the heterogeneity of cancer cells is generally...
# 7568  1  "adipogenesis is the process through which mes...
# 7569  1  the periparturient period is one of the most c...
#
# [7570 rows x 2 columns]

# %% [markdown]
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:black; background-color:#dfa8e4; font-size: 16px; border-width: 2px; font-weight: bold;" data-toggle="popover">
# <span style="font-size: 20px;">Lower String</span></a>

# %%
med.x=med.x.str.lower()
# before doing any analysis convert data into lower or upper

# %%
med.head()
# Out:
#    y                                                  x
# 0  0  thyroid surgery in  children in a single insti...
# 1  0  " the adopted strategy was the same as that us...
# 2  0  coronary arterybypass grafting thrombosis ï¬b...
# 3  0   solitary plasmacytoma sp of the skull is an u...
# 4  0   this study aimed to investigate serum matrix ...

# %% [markdown]
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:black; background-color:#dfa8e4; font-size: 16px; border-width: 2px; font-weight: bold;" data-toggle="popover">
# <span style="font-size: 20px;">Stop words</span></a>

# %%
#Reduction of Dimensionality,Improved Performance,Reduced Noise,Better Interpretability

# %%
from nltk.corpus import stopwords
l1=stopwords.words("english")
# we remove them

# %% [markdown]
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:black; background-color:#dfa8e4; font-size: 16px; border-width: 2px; font-weight: bold;" data-toggle="popover">
# <span style="font-size: 20px;">punctuation</span></a>

# %%
#Simplifying Tokenization,Normalization,Reducing Noise,Enhancing Interpretability

# %%
import string

string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def text_process(mess):
    """
    1. remove the punctuation
    2. remove the stopwords
    3. return the list of clean textwords
    
    """
    nopunc=[char for char in mess if char not in string.punctuation]
    nopunc="".join(nopunc)
    
    return [word for word in nopunc.split() if word not in l1]

# %%
med['x'].apply(text_process)
# Out:
# 0       [thyroid, surgery, children, single, instituti...
# 1       [adopted, strategy, used, prior, years, based,...
# 2       [coronary, arterybypass, grafting, thrombosis,...
# 3       [solitary, plasmacytoma, sp, skull, uncommon, ...
# 4       [study, aimed, investigate, serum, matrix, met...
#                               ...
# 7565    [report, case, 24yearold, man, presented, chie...
# 7566    [among, synchronous, colorectal, cancers, scrc...
# 7567    [heterogeneity, cancer, cells, generally, acce...
# 7568    [adipogenesis, process, mesenchymalstem, cells...
# 7569    [periparturient, period, one, challenging, per...
# Name: x, Length: 7570, dtype: object

# %% [markdown]
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:black; background-color:#dfa8e4; font-size: 16px; border-width: 2px; font-weight: bold;" data-toggle="popover">
# <span style="font-size: 20px;">Create TDM</span></a>

# %%
from sklearn.feature_extraction.text import CountVectorizer  # this is used to count each and every unique word...

# %%
import timeit
start=timeit.default_timer()

bow_transformer=CountVectorizer(analyzer=text_process).fit(med['x'])

stop=timeit.default_timer()
execution_time=stop-start
print("Program executed in ",execution_time)
# Out:
# Program executed in  107.04783120000502

# %%
bow_transformer=CountVectorizer(analyzer=text_process).fit(med['x'])

# %%
bow_transformer.vocabulary_
# Out:
# {'thyroid': 184741,
#  'surgery': 175947,
#  'children': 46891,
#  'single': 168501,
#  'institution': 98617,
#  'osama': 136431,
#  'ibrahim': 92838,
#  'almosallama': 20757,
#  'ali': 20228,
#  'aseerib': 29353,
#  'ahmed': 19380,
#  'alhumaida': 20227,
#  'alzahranic': 21414,
#  'saif': 162107,
#  'alsobhib': 21042,
#  'saud': 162972,
#  'alshanafeybfrom': 21011,
#  'adepartment': 17640,
#  'college': 50334,
#  'medicine': 115868,
#  'qassim': 152212,
#  'university': 192186,
#  'buraidah': 38772,
#  'al': 19740,
#  'saudi': 162975,
#  'arabia': 28159,
#  'bdepartment': 33374,
#  'king': 104964,
#  'faisal': 73922,
#  'specialist': 170954,
#  'hospital': 90004,
#  'research': 157570,
#  'center': 45364,
#  'riyadh': 159726,
#  'cdepartment': 44123,
#  'correspondence': 53898,
#  'dr': 64913,
#  'almosallam': 20756,
#  'department': 59660,
#  'po': 145525,
#  'box': 37574,
#  'osamaiaahotmailcom': 136432,
#  'orcid': 135793,
#  'orcid0000000290367564': 135798,
#  'citation': 48335,
#  'oi': 134246,
#  'aseeri': 29352,
#  'alhumaid': 20226,
#  'alzahrani': 21413,
#  'alsobhi': 21041,
#  'alshanafey': 21010,
#  'ann': 25927,
#  'med': 115600,
#  'received': 154801,
#  'january': 102379,
#  'accepted': 15844,
#  'may': 114668,
#  'published': 151561,
#  'august': 31203,
#  'copyright': 53617,
#  'annals': 25930,
#  'access': 15852,
#  'creative': 54888,
#  'commons': 50876,
#  'attributionnoncommercialnoderivatives': 31063,
#  'international': 99394,
#  'license': 108720,
#  'cc': 43477,
#  'byncnd': 39432,
#  'details': 60228,
#  'accessed': 15867,
#  'httpcreativecommons': 90903,
#  'licensesbyncnd40funding': 108728,
#  'nonebackground': 128856,
#  'data': 57531,
#  'scarceobjective': 163250,
#  'analyze': 22594,
#  'outcome': 137096,
#  'pediatric': 141816,
#  'populationdesign': 146286,
#  'medical': 115767,
#  'record': 155250,
#  'reviewsetting': 158988,
#  'tertiary': 179215,
#  'health': 87100,
#  'care': 42341,
#  'institutionpatients': 98636,
#  'methods': 117541,
#  'collected': 50254,
#  'demographic': 59394,
#  'clinical': 48922,
#  'patients': 140529,
#  'years': 202001,
#  'younger': 202493,
#  'period': 142510,
#  'descriptive': 60030,
#  'presentedmain': 148249,
#  'measures': 115434,
#  'indications': 96437,
#  'thyroidectomy': 184770,
#  'pathology': 140125,
#  'complications': 51337,
#  'length': 107948,
#  'stay': 172761,
#  'radioactive': 153143,
#  'iodine': 100619,
#  'treatment': 188456,
#  'recurrencessample': 155450,
#  'size': 168962,
#  'results': 158460,
#  'underwent': 191878,
#  'procedures': 149063,
#  'females': 74864,
#  'mean': 115261,
#  'age': 18841,
#  'operation': 135419,
#  'associated': 30145,
#  'multiple': 123723,
#  'endocrine': 68701,
#  'neoplasia': 126567,
#  'type': 190718,
#  'history': 89200,
#  'radiation': 153088,
#  'exposure': 72630,
#  'eightyone': 67667,
#  'fine': 75743,
#  'needle': 126281,
#  'aspiration': 29746,
#  'fna': 76479,
#  'correlated': 53841,
#  'final': 75617,
#  'histopathology': 89182,
#  'cases': 42775,
#  'sixtysix': 168950,
#  'malignant': 113049,
#  'cancer': 40657,
#  'papillary': 139263,
#  'neck': 126183,
#  'dissection': 63142,
#  'lymph': 111809,
#  'node': 128344,
#  'metastasis': 117216,
#  'distant': 63221,
#  'metastases': 117170,
#  'lung': 111554,
#  'included': 95680,
#  'total': 187154,
#  'hemithyroidectomy': 87661,
#  'completion': 51230,
#  'subtotal': 174980,
#  'twentythree': 190519,
#  'developed': 60486,
#  'hypocalcemia': 92434,
#  'permanent': 142667,
#  'unilateral': 192035,
#  'recurrent': 155460,
#  'laryngeal': 107082,
#  'nerve': 126681,
#  'injury': 97878,
#  'followed': 76638,
#  'duration': 65637,
#  'months': 122036,
#  'median': 115656,
#  'recurrence': 155404,
#  'malignancy': 113026,
#  'commonest': 50841,
#  'indication': 96433,
#  'highly': 88690,
#  'diagnostic': 61136,
#  'significant': 167811,
#  'rate': 153956,
#  'limitations': 109143,
#  'retrospectiveconflict': 158776,
#  'interest': 99143,
#  'noneoriginal': 128885,
#  'julyaugust': 103296,
#  'wwwannsaudimednet': 201045,
#  '0cthyroid': 1681,
#  'diseases': 62701,
#  'requiring': 157497,
#  'relatively': 156592,
#  'uncommon': 191645,
#  'compared': 51006,
#  'adults': 18108,
#  'prevalence': 148428,
#  'palpable': 138894,
#  'nodules': 128458,
#  'ranges': 153672,
#  'sporadic': 171535,
#  'welldifferentiated': 197782,
#  'common': 50827,
#  'accounting': 15980,
#  'cancers': 41277,
#  'prepubertal': 148157,
#  'group': 84142,
#  'adolescents': 17990,
#  'aged': 18875,
#  '\x93': 203899,
#  'year2': 201964,
#  'varies': 194350,
#  'among': 21769,
#  'studies': 173964,
#  'conditions': 51920,
#  'rising38': 159586,
#  'throughout': 184579,
#  'world': 200723,
#  'scarce': 163244,
#  'objective': 131127,
#  'study': 174167,
#  'large': 106968,
#  'series': 165671,
#  'treated': 188419,
#  'kfshrc': 104532,
#  'riyadhpatient': 159727,
#  'approval': 27998,
#  'institutional': 98618,
#  'review': 158931,
#  'board': 36867,
#  'irb': 100904,
#  'records': 155276,
#  'old': 134344,
#  'retrospectively': 158780,
#  'reviewed': 158948,
#  'elected': 67830,
#  'include': 95673,
#  'year': 201960,
#  'ensure': 69341,
#  'reasonable': 154690,
#  'followup': 76731,
#  'identified': 93110,
#  'search': 164402,
#  'operating': 135416,
#  'room': 160361,
#  'log': 110485,
#  'involving': 100513,
#  'gland': 82360,
#  'specified': 171074,
#  'groupdemographic': 84197,
#  'features': 74598,
#  'surgical': 176080,
#  'outcomes': 137129,
#  'specific': 171016,
#  'obtained': 131316,
#  'gender': 80838,
#  'family': 74022,
#  'presenting': 148262,
#  'symptoms': 176798,
#  'presence': 148196,
#  'men': 116531,
#  'function': 79011,
#  'test': 179253,
#  'ultrasound': 191429,
#  'nodes': 128377,
#  'cytology': 56809,
#  'procedure': 149037,
#  'analyzed': 22596,
#  'postoperative': 146818,
#  'including': 95762,
#  'transient': 188087,
#  'paralysis': 139382,
#  'wound': 200837,
#  'infection': 96889,
#  'hematoma': 87614,
#  'recurrences': 155446,
#  'surgeries': 175942,
#  'performed': 142371,
#  'either': 67705,
#  'adult': 18081,
#  'surgeon': 175908,
#  'intraoperative': 99986,
#  'monitoring': 121815,
#  'used': 193017,
#  'early': 66459,
#  'surgeons': 175915,
#  'lately': 107182,
#  'combined': 50673,
#  'approach': 27909,
#  'adopted': 18003,
#  'collaborated': 50186,
#  'proceduresthe': 149092,
#  'normal': 129514,
#  'range': 153633,
#  'laboratory': 106441,
#  'regardless': 155944,
#  'lasted': 107151,
#  'less': 108160,
#  'considered': 52405,
#  'serum': 165769,
#  'calcium': 40287,
#  'level': 108339,
#  'remained': 156734,
#  'patient': 140437,
#  'continued': 52808,
#  'supplementation': 175625,
#  'genetic': 81377,
#  'testing': 179337,
#  'ret': 158650,
#  'protooncogene': 150828,
#  'confirm': 52077,
#  'diagnosis': 61060,
#  'preoperative': 147997,
#  'vocal': 195995,
#  'cords': 53649,
#  'assessment': 30026,
#  'otolaryngology': 136916,
#  'clinic': 48920,
#  'generated': 81089,
#  'comparisons': 51053,
#  'conducted': 51990,
#  'using': 193195,
#  'continuous': 52864,
#  'chisquare': 47174,
#  'fisher': 75926,
#  'exact': 71691,
#  'tests': 179400,
#  'proportionsresultsbetween': 150228,
#  'two': 190547,
#  'disease': 62454,
#  'eighty': 67663,
#  'nodule': 128444,
#  'present': 148202,
#  'table': 177546,
#  'sd': 164228,
#  'mm': 120726,
#  'syndromes': 176929,
#  'syndrome': 176874,
#  'showed': 167127,
#  'medullary': 116051,
#  'mtc': 123274,
#  'remaining': 156751,
#  'prophylactic': 150185,
#  'development': 60533,
#  'none': 128851,
#  'three': 184360,
#  'toxic': 187360,
#  'adenoma': 17590,
#  'one': 134872,
#  'case': 42734,
#  'graves\x99': 83822,
#  'require': 157448,
#  'another': 26091,
#  'repeated': 157027,
#  'came': 40513,
#  'documented': 63997,
#  'first': 75831,
#  'hospitalthe': 90122,
#  'diagnoses': 61046,
#  'multinodular': 123697,
#  'goiter': 83115,
#  'colloid': 50370,
#  'indicationnodulen': 96436,
#  'prophylaxishyperthyroidismmultinodular': 150191,
#  'goitercompletion': 83117,
#  'defined': 58918,
#  'levels': 108405,
#  'number': 130704,
#  'original': 135995,
#  'surgeryann': 175968,
#  '0cnodule': 1521,
#  'operative': 135440,
#  'observed': 131206,
#  'complication': 51328,
#  'patientspathologyn': 140821,
#  'benignnormal': 34325,
#  'tissuecolloid': 185300,
#  'nodulecystadenomathyroiditisgraves\x99': 128447,
#  'diseasethyroid': 62857,
#  'cancerpapillaryfollicularmedullaryhurthleanaplastictotaldata': 41187,
#  'benign': 34319,
#  'lesions': 108103,
#  'patientsbenignn37malignantn66': 140627,
#  'p': 137864,
#  'value': 193896,
#  'meanyearsgender': 115350,
#  'malefemalepresence': 112932,
#  'nodulehypocalcemiarecurrent': 128450,
#  'palsybleedinghematomawound': 138908,
#  'infectiontracheal': 96995,
#  'injuryoverall': 97900,
#  'complicationsmean': 51365,
#  'daysmen': 58059,
#  'palsy': 138907,
#  'bleeding': 36375,
#  'tracheal': 187549,
#  'delivered': 59250,
#  'local': 110293,
#  'rai': 153399,
#  'low': 110917,
#  'risk': 159590,
#  'receive': 154794,
#  'five': 75995,
#  'clear': 48789,
#  'whether': 198648,
#  'resection': 157746,
#  'except': 71849,
#  'lost': 110857,
#  'follow': 76637,
#  'mortality': 122476,
#  'discussionthe': 62441,
#  'correlates': 53847,
#  'previously': 148533,
#  'reports': 157252,
#  'population35': 146261,
#  'estimated': 70803,
#  'fourfold': 77876,
#  'higher': 88507,
#  'developing': 60521,
#  'adults910': 18111,
#  'high': 88440,
#  'incidence': 95613,
#  'suggests': 175244,
#  'carefully': 42390,
#  'evaluatedfna': 71300,
#  'valuablemethod': 193890,
#  'evaluation': 71328,
#  'however': 90273,
#  'routine': 160597,
#  'use': 192998,
#  'need': 126253,
#  'sedation': 164683,
#  'sampling': 162568,
#  'errors': 70384,
#  'limited': 109160,
#  'availability': 31601,
#  'experienced': 72364,
#  'cytopathologists11': 56868,
#  'many': 113536,
#  'previous': 148521,
#  'reported': 157143,
#  'sensitivity': 165329,
#  'specificity': 171044,
#  'evaluating': 71322,
#  'children1114': 46892,
#  'correlate': 53840,
#  'findingsour': 75716,
#  'supports': 175717,
#  'notion': 129919,
#  'frequently': 78349,
#  'extensive': 73013,
#  'lymphnode': 111838,
#  'involvement': 100481,
#  'seen': 164762,
#  'differentiated': 61583,
#  'cancer1523': 40680,
#  'largest': 107026,
#  'referral': 155832,
#  'especially': 70657,
#  'oncology': 134761,
#  'explain': 72520,
#  'cohortthe': 50006,
#  'hypoparathyroidism': 92500,
#  'ranging': 153703,
#  '0ccorresponds': 1273,
#  'found': 77808,
#  'central': 45416,
#  'bilateral': 35283,
#  'factors': 73659,
#  'surgery3': 175954,
#  'cohort': 49929,
#  'noted': 129828,
#  'failed': 73868,
#  'reach': 154411,
#  'statistical': 172593,
#  'significance': 167781,
#  'moreover': 122304,
#  'difference': 61467,
#  'terms': 179168,
#  'distribution': 63302,
#  'overall': 137371,
#  'finding': 75685,
#  'previously26': 148542,
#  'recent': 154851,
#  'inverse': 100305,
#  'relationship': 156552,
#  'volume': 196055,
#  'rates2728': 154014,
#  'similar': 168273,
#  'population': 146251,
#  'lacking': 106514,
#  'highvolume': 88815,
#  'better': 34766,
#  'shorter': 167051,
#  'lengths': 107963,
#  'lower': 110963,
#  'costs': 54057,
#  'parathyroidectomy': 139493,
#  'general': 81029,
#  'otolaryngologists29': 136915,
#  'scheumann': 163478,
#  'colleagues': 50243,
#  'also': 21025,
#  'concluded': 51798,
#  'collaborative': 50195,
#  'would': 200815,
#  'led': 107733,
#  'authors': 31356,
#  'suggest': 175212,
#  'addition': 17323,
#  'endocrinologists': 68719,
#  'optimize': 135581,
#  'given': 82298,
#  'patients4': 140558,
#  'allow': 20641,
#  'different': 61530,
#  'approaches': 27929,
#  'late': 107177,
#  'adoption': 18012,
#  'varied': 194342,
#  'widely': 199086,
#  'explored': 72575,
#  'predictors': 147761,
#  'male': 112915,
#  'histologic': 89103,
#  'subtype': 174989,
#  'advanced': 18138,
#  'tumor': 189871,
#  'stage': 172027,
#  'recurrence17233033': 155405,
#  'although': 21301,
#  'conflicting': 52108,
#  'regarding': 155927,
#  'lowrisk': 111098,
#  'current': 56125,
#  'recommendation': 155171,
#  'without': 199938,
#  'rai3436there': 153404,
#  'retrospective': 158771,
#  'nature': 125627,
#  'affect': 18396,
#  'validity': 193856,
#  'quality': 152476,
#  'small': 169461,
#  'categories': 43111,
#  'enable': 68560,
#  'us': 192848,
#  'compare': 51005,
#  'groups': 84311,
#  'explore': 72573,
#  'relative': 156580,
#  'hand': 86038,
#  'adds': 17464,
#  'cancerrelated': 41252,
#  'death': 58344,
#  'extremely': 73193,
#  'rare': 153835,
#  'treatmentoriginal': 188628,
#  '0creferences': 1591,
#  'trowbridge': 189349,
#  'fl': 76053,
#  'matovinovic': 114415,
#  'j': 102172,
#  'mclaren': 115017,
#  'gd': 80609,
#  'nichaman': 127597,
#  'mz': 124572,
#  'pediatrics': 141824,
#  'ries': 159408,
#  'lag': 106637,
#  'melbert': 116308,
#  'krapcho': 105793,
#  'stinchcomb': 173169,
#  'dg': 60842,
#  'howlader': 90368,
#  'n': 124612,
#  'horner': 89951,
#  'mj': 120590,
#  'et': 70914,
#  'seer': 164776,
#  'statistics': 172631,
#  'bethesda': 34755,
#  'national': 125550,
#  'institute': 98587,
#  'based': 32953,
#  'november': 130110,
#  'submission': 174778,
#  'chen': 46677,
#  'yh': 202282,
#  'masiakos': 114123,
#  'pt': 151334,
#  'gaz': 80433,
#  'rd': 154372,
#  'hodin': 89496,
#  'ra': 152949,
#  'parangi': 139464,
#  'randolph': 153565,
#  'gw': 85291,
#  'pediatr': 141814,
#  'surg': 175880,
#  'aug5081316': 31185,
#  'wood': 200548,
#  'jh': 102704,
#  'partrick': 139850,
#  'da': 57113,
#  'barham': 32792,
#  'hp': 90400,
#  'bensard': 34360,
#  'dd': 58224,
#  'travers': 188380,
#  'hs': 90584,
#  'bruny': 38414,
#  'jl': 102906,
#  'may4658238': 114672,
#  'scholz': 163597,
#  'smith': 169616,
#  'jr': 103197,
#  'chaignaud': 45859,
#  'b': 32066,
#  'shamberger': 166482,
#  'rc': 154318,
#  'huang': 91541,
#  'sa': 161888,
#  'children\x99s': 46905,
#  'boston': 37321,
#  '35year': 9368,
#  'singleinstitution': 168543,
#  'experience': 72358,
#  'mar46343742': 113676,
#  'josefson': 103080,
#  'zimmerman': 203213,
#  'endocrinol': 68711,
#  'rev': 158825,
#  'sep611423': 165410,
#  'hameed': 85979,
#  'r': 152837,
#  'zacharin': 202782,
#  'mr': 122965,
#  'changing': 46050,
#  'face': 73470,
#  'paediatric': 138615,
#  'adolescent': 17987,
#  'paediatr': 138614,
#  'child': 46864,
#  'lugovicente': 111460,
#  'h': 85400,
#  'ortiz': 136359,
#  'vn': 195983,
#  'irizarry': 100980,
#  'camps': 40588,
#  'ji': 102725,
#  'pagã¡n': 138676,
#  'v': 193527,
#  'management': 113181,
#  'era': 70134,
#  'aspirationj': 29747,
#  'mussa': 124065,
#  'de': 58276,
#  'andrea': 24819,
#  'motta': 122715,
#  'mormile': 122423,
#  'palestini': 138831,
#  'corrias': 53928,
#  'oct167488692': 131523,
#  'amirazodi': 21706,
#  'e': 66039,
#  'propst': 150256,
#  'ej': 67730,
#  'chung': 47669,
#  'ct': 55607,
#  'parra': 139632,
#  'wasserman': 197071,
#  'jd': 102571,
#  'biopsy': 35940,
#  'impact': 94948,
#  'cytopathol': 56866,
#  'partyka': 139866,
#  'kl': 105146,
#  'ec2': 66637,
#  'cramer': 54716,
#  'hm': 89355,
#  'wu': 200984,
#  'hh': 88287,
#  'fineneedle': 75754,
#  'aspirates': 29745,
#  'sinha': 168596,
#  'ck': 48481,
#  'decoppi': 58665,
#  'pierro': 144292,
#  'brain': 37742,
#  'c': 39716,
#  'hindmarsh': 88902,
#  'butler': 38939,
#  'g': 79602,
#  'eur': 71194,
#  'oct2554259': 131526,
#  'kundel': 106116,
#  'thompson': 184203,
#  'gb': 80444,
#  'richards': 159362,
#  'ml': 120629,
#  'qiu': 152298,
#  'lx': 111758,
#  'cai': 40215,
#  'schwenk': 163693,
#  'fw': 79546,
#  '20year': 7193,
#  'mayo': 114722,
#  'clin': 48904,
#  'metab': 116937,
#  'february': 74673,
#  'jiang': 102742,
#  'w': 196356,
#  'newbury': 127244,
#  'ro': 160031,
#  'newfield': 127264,
#  'rs': 160820,
#  'nodulesan': 128462,
#  '10year': 3966,
#  'int': 98801,
#  'burke': 38834,
#  'jf': 102685,
#  'sippel': 168672,
#  'evolution': 71618,
#  'res': 157510,
#  'alqahtani': 20958,
#  'kh': 104604,
#  'tunio': 190377,
#  'asiri': 29540,
#  'aljohani': 20332,
#  'nj': 127981,
#  'bayoumi': 33178,
#  'riaz': 159293,
#  'k': 103455,
#  'clinicopathological': 49074,
#  'otolaryngol': 136911,
#  'head': 87049,
#  'nov': 130042,
#  'kluijfhout': 105262,
#  'wp': 200862,
#  'van': 194074,
#  'beek': 33654,
#  'dj': 63563,
#  'verrijn': 195003,
#  'stuart': 173924,
#  'aa': 14894,
#  'lodewijk': 110469,
#  'l': 106310,
#  'valk': 193865,
#  'der': 59832,
#  'zee': 202916,
#  'dc': 58149,
#  'young': 202488,
#  'baltimore': 32612,
#  '20159429e1108': 6709,
#  'raval': 154220,
#  'mv': 124289,
#  'browne': 38347,
#  'chin': 46935,
#  'ac': 15746,
#  'angelos': 25597,
#  'reynolds': 159067,
#  'patient\x94feasible': 141014,
#  'safe': 162037,
#  'stavrakis': 172758,
#  'ai': 19419,
#  'ituarte': 102019,
#  'ph': 143260,
#  'ko': 105437,
#  'cy': 56416,
#  'yeh': 202171,
#  'mw': 124309,
#  'predictor': 147757,
#  'inpatient': 98229,
#  'outpatient': 137286,
#  'sosa': 170585,
#  'ja': 102188,
#  'bowman': 37571,
#  'tielsch': 184925,
#  'jm': 102924,
#  'powe': 147177,
#  'nr': 130252,
#  'gordon': 83330,
#  'ta': 177519,
#  'udelsman': 191166,
#  'importance': 95102,
#  'economic': 66791,
#  'tuggle': 189832,
#  'roman': 160304,
#  'wang': 196584,
#  'ts': 189457,
#  'boudourakis': 37473,
#  'thomas': 184191,
#  'dec144686977': 58482,
#  'park': 139575,
#  'jeong': 102638,
#  'js': 103208,
#  'ryu': 161401,
#  'hr': 90485,
#  'lee': 107753,
#  'kang': 103708,
#  'carcinoma': 42054,
#  'adolescents27year': 17991,
#  'yonsei': 202436,
#  'system': 177065,
#  'korean': 105630,
#  'sci': 163704,
#  'palmer': 138873,
#  'ba': 32168,
#  'zarroug': 202861,
#  'ae': 18255,
#  'poley': 145707,
#  'rn': 159825,
#  'kollars': 105540,
#  'jp': 103168,
#  'moir': 121582,
#  'cr': 54680,
#  'wada': 196415,
#  'sugino': 175260,
#  'mimura': 119251,
#  'nagahama': 124993,
#  'kitagawa': 105051,
#  'shibuya': 166815,
#  'factor': 73561,
#  'analysis': 22271,
#  'free': 78255,
#  'survival': 176192,
#  'bmc': 36739,
#  'danese': 57385,
#  'gardini': 80167,
#  'farsetti': 74188,
#  'sciacchitano': 163713,
#  'andreoli': 24875,
#  'pontecorvi': 146129,
#  'astl': 30362,
#  'chovanec': 47439,
#  'lukes': 111478,
#  'katra': 103976,
#  'dvorakova': 65788,
#  'vlcek': 195968,
#  'otorhinolaryngol': 136919,
#  'chaukar': 46332,
#  'rangarajan': 153632,
#  'nair': 125051,
#  'nadkarni': 124965,
#  'ms': 123143,
#  'pai': 138683,
#  'ps': 151127,
#  'dcruz': 58196,
#  'ak': 19604,
#  'oncol': 134704,
#  'dzodic': 65995,
#  'buta': 38905,
#  'markovic': 113946,
#  'gavrilo': 80425,
#  'matovic': 114414,
#  'milovanovic': 119210,
#  'z': 202744,
#  'serbia': 165651,
#  'endocr': 68700,
#  'gf': 81881,
#  'gimm': 82183,
#  'wegener': 197569,
#  'hundeshagen': 91898,
#  'dralle': 64949,
#  'prognostic': 149554,
#  'locoregional': 110445,
#  'shi': 166807,
#  'rl': 159758,
#  'qu': 152434,
#  'yang': 201779,
#  'sw': 176540,
#  'interpretation': 99483,
#  'predicting': 147717,
#  'cervical': 45618,
#  'model': 121113,
#  'onco': 134637,
#  'targets': 178137,
#  'ther': 182580,
#  'hay': 86666,
#  'id': 93034,
#  'gough': 83393,
#  'ir': 100855,
#  'goellner': 83086,
#  'ryan': 161381,
#  'jj': 102878,
#  'grant': 83681,
#  'cs': 55471,
#  'longterm': 110679,
#  'conservatively': 52364,
#  'decades': 58499,
#  'collini': 50362,
#  'mattavelli': 114503,
#  'f': 73363,
#  'pellegrinelli': 141932,
#  'barisella': 32804,
#  'ferrari': 74991,
#  'massimino': 114192,
#  'childhood': 46874,
#  'adolescence': 17985,
#  'morphologic': 122439,
#  'subtypes': 175005,
#  'biologic': 35665,
#  'behavior': 33869,
#  'prognosis': 149481,
#  'clinicopathologic': 49073,
#  '30year': 9062,
#  'pathol': 140062,
#  'borsonchazot': 37301,
#  'causeret': 43322,
#  'lifante': 108795,
#  'jc': 102530,
#  'augros': 31200,
#  'berger': 34475,
#  'peix': 141913,
#  'predictive': 147745,
#  'baumgarten': 33144,
#  'hd': 86948,
#  'bauer': 33132,
#  'aj': 19575,
#  'isaza': 101123,
#  'mostoufimoab': 122617,
#  'kazahaya': 104052,
#  'adzick': 18253,
#  'ns': 130343,
#  'rates': 154012,
#  'philadelphia': 143661,
#  'journal': 103108,
#  'oct': 131521,
#  'kurzawinski': 106177,
#  'tr': 187514,
#  'coppi': 53590,
#  'inpediatric': 98239,
#  'pp': 147224,
#  'springer': 171618,
#  'berlin': 34517,
#  'heidelberg': 87397,
#  'francis': 78184,
#  'waguespack': 196429,
#  'sg': 166382,
#  'angelog': 25595,
#  'benvenga': 34370,
#  'guidelines': 85036,
#  'american': 21579,
#  'association': 30173,
#  'task': 178211,
#  'force': 76967,
#  '0c': 1144,
#  'strategy': 173491,
#  'prior': 148800,
#  'four': 77865,
#  'exclusive': 71951,
#  'queries': 152666,
#  'return': 158809,
#  'disjoint': 62929,
#  'subsets': 174891,
#  'query': 152669,
#  'qpubplain': 152365,
#  'plaintext': 144758,
#  'pubmed': 151586,
#  'titles': 185520,
#  'keywords': 104521,
#  'second': 164473,
#  'qpubindexed': 152364,
#  'relies': 156707,
#  'indexing': 96319,
#  'scheme': 163454,
#  'mesh': 116824,
#  'made': 112434,
#  'set': 165936,
#  'third': 183930,
#  'qwosrestricted': 152825,
#  'wos': 200808,
#  'restricted': 158414,
#  'areas': 28341,
#  '\x9cmedical': 206218,
#  'informatics\x9d': 97228,
#  '\x9chealth': 206057,
#  'sciences': 163741,
#  'services\x9d': 165886,
#  'fourth': 77910,
#  'qwosfiltered': 152824,
#  'filtered': 75601,
#  'nonrelevant': 129237,
#  'eg': 67380,
#  'archeology': 28256,
#  'dance': 57370,
#  'zoology': 203372,
#  'etc': 70937,
#  'note': 129827,
#  'select': 164880,
#  'nonpubmedindexed': 129204,
#  'papers': 139251,
#  'supposed': 175729,
#  'caught': 43278,
#  'queriesa': 152667,
#  'retrieved': 158746,
#  'citations': 48357,
#  'section': 164613,
#  'editors': 66960,
#  'candidate': 41555,
#  'best': 34621,
#  'following': 76645,
#  'imia': 94462,
#  'yearbook': 201973,
#  'protocol': 150765,
#  'individually': 96530,
#  'rated': 153975,
#  'chief': 46848,
#  'editor': 66946,
#  'decision': 58557,
#  'support': 175683,
#  ...}

# %%
len(bow_transformer.vocabulary_)
# there are 208269 unique words after removing punctuation and stopwords
# that when we create our TDM our tdm will have 208269 columns
# Out:
# 208269

# %%
tdm=bow_transformer.transform(med['x'])

# %%
tdm.shape
# Out:
# (7570, 208269)

# %%
type(tdm)
# Out:
# scipy.sparse._csr.csr_matrix

# %% [markdown]
# ## <p style="background-color:#B61151; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;"> Pre-Processing Data  <p>
#
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:black; background-color:#dfa8e4; font-size: 16px; border-width: 2px; font-weight: bold;" data-toggle="popover">
#     <span style="font-size: 20px;">Spliting Data into Train and Test</span>
# </a>

# %%
# tdm is like our x variable 
from sklearn.model_selection import train_test_split
tdm_train,tdm_test,train_y,test_y=train_test_split(tdm,med['y'],test_size=.2)

train_y.shape
# Out:
# (6056,)

# %%
tdm_train.shape
# Out:
# (6056, 208269)

# %% [markdown]
# ## <p style="background-color:#B61151; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;"> Naive Bayes  <p>
#
# ### In a project, you could describe Naive Bayes as "a simple probabilistic classifier based on Bayes' theorem with the assumption of independence between features."

# %%
from sklearn.naive_bayes import MultinomialNB

nb=MultinomialNB()
nb.fit(tdm_train,train_y)
# Out:
# MultinomialNB()

# %%
pred_nb=nb.predict(tdm_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
tab_nb=confusion_matrix(test_y,pred_nb)
tab_nb
# Out:
# array([[491,  62,   0],
#        [ 44, 485,   0],
#        [  0,   0, 432]], dtype=int64)

# %%
accuracy_score(test_y,pred_nb)
# Out:
# 0.9299867899603699

# %%
print(classification_report(test_y,pred_nb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.89      0.90       553
#            1       0.89      0.92      0.90       529
#            2       1.00      1.00      1.00       432
#
#     accuracy                           0.93      1514
#    macro avg       0.93      0.93      0.93      1514
# weighted avg       0.93      0.93      0.93      1514

# %% [markdown]
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:black; background-color:#dfa8e4; font-size: 16px; border-width: 2px; font-weight: bold;" data-toggle="popover">
#     <span style="font-size: 20px;"> Most Frequent Words from all data</span>

# %%
import matplotlib.pyplot as plt

# %%
from wordcloud import WordCloud
cloud=WordCloud(stopwords=stopwords.words('english'),max_words=30).generate(str(med['x']))
plt.figure(figsize=(10,10))
plt.imshow(cloud)

# %% [markdown]
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:black; background-color:#dfa8e4; font-size: 16px; border-width: 2px; font-weight: bold;" data-toggle="popover">
#     <span style="font-size: 20px;">Most Frequent Words from class 0 -->Thyroid_Cancer</span>

# %%
med_spam_df0=med[med.y==0]

# %%
from wordcloud import WordCloud
cloud=WordCloud(stopwords=stopwords.words('english'),max_words=40).generate(str(med_spam_df0['x']))
plt.figure(figsize=(10,10))
plt.imshow(cloud)

# %% [markdown]
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:black; background-color:#dfa8e4; font-size: 16px; border-width: 2px; font-weight: bold;" data-toggle="popover">
#     <span style="font-size: 20px;">Most Frequent Words from class 1 -->Colon_Cancer</span>

# %%
med_spam_df1=med[med.y==1]

# %%
cloud=WordCloud(stopwords=stopwords.words('english'),max_words=40).generate(str(med_spam_df1['x']))
plt.figure(figsize=(10,10))
plt.imshow(cloud)

# %% [markdown]
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:black; background-color:#dfa8e4; font-size: 16px; border-width: 2px; font-weight: bold;" data-toggle="popover">
#     <span style="font-size: 20px;">Most Frequent Words from class 2 --> Lung_Cancer</span>

# %%
med_spam_df2=med[med.y==2]

# %%
cloud=WordCloud(stopwords=stopwords.words('english'),max_words=40).generate(str(med_spam_df2['x']))
plt.figure(figsize=(10,10))
plt.imshow(cloud)

# %% [markdown]
# ## <p style="background-color:#B61151; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">RNN  <p>
# ### "RNNs are a type of neural network architecture designed to effectively process sequential data by retaining information about previous inputs. They achieve this by incorporating loops within their structure, allowing them to maintain a memory of past information while processing new input. This makes RNNs particularly suitablefor tasks such as time series prediction, natural language processing, and sequence generation.

# %%
pd.read_csv(r"D:\Medical.csv",encoding='latin-1')
# Out:
#       Unnamed: 0               0  \
# 0              0  Thyroid_Cancer
# 1              1  Thyroid_Cancer
# 2              2  Thyroid_Cancer
# 3              3  Thyroid_Cancer
# 4              4  Thyroid_Cancer
# ...          ...             ...
# 7565        7565    Colon_Cancer
# 7566        7566    Colon_Cancer
# 7567        7567    Colon_Cancer
# 7568        7568    Colon_Cancer
# 7569        7569    Colon_Cancer
#
#                                                       a
# 0     Thyroid surgery in  children in a single insti...
# 1     " The adopted strategy was the same as that us...
# 2     coronary arterybypass grafting thrombosis ï¬b...
# 3      Solitary plasmacytoma SP of the skull is an u...
# 4      This study aimed to investigate serum matrix ...
# ...                                                 ...
# 7565  we report the case of a 24yearold man who pres...
# 7566  among synchronous colorectal cancers scrcs rep...
# 7567  the heterogeneity of cancer cells is generally...
# 7568  "adipogenesis is the process through which mes...
# 7569  the periparturient period is one of the most c...
#
# [7570 rows x 3 columns]

# %%
med=pd.read_csv(r"D:\Medical.csv",encoding='latin-1')

# %%
df=pd.DataFrame(med['0'])

# %%
df['x']=med['a']

# %%
df.rename(columns={'0':'y'},inplace=True)

# %%
df.y=df.y.replace({'Thyroid_Cancer':0,'Colon_Cancer':1,'Lung_Cancer':2})

# %%
df.head()
# Out:
#    y                                                  x
# 0  0  Thyroid surgery in  children in a single insti...
# 1  0  " The adopted strategy was the same as that us...
# 2  0  coronary arterybypass grafting thrombosis ï¬b...
# 3  0   Solitary plasmacytoma SP of the skull is an u...
# 4  0   This study aimed to investigate serum matrix ...

# %%
df.y.nunique()
# Out:
# 3

# %%
df.isnull().sum()[df.isnull().sum()>0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:black; background-color:#dfa8e4; font-size: 16px; border-width: 2px; font-weight: bold;" data-toggle="popover">
#     <span style="font-size: 20px;">Spliting Data into Train and Test</span>
# </a>

# %%
df_x=df.iloc[:,1]
df_y=df.iloc[:,0]
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(df_x,df_y,test_size=.2)

# %%
from tensorflow.keras.utils import to_categorical

# Assuming y_train and y_test are your class labels
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
max_num_words=8000 #from entire corpus sleect 10000 words
seq_len=100 # how many words out of 10000 you wish to take from each document
embedding_size=100 #vector length of each word

# %% [markdown]
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:black; background-color:#dfa8e4; font-size: 16px; border-width: 2px; font-weight: bold;" data-toggle="popover">
#     <span style="font-size: 20px;">Sampling</span>
# </a>

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

# %%
tokenizer=Tokenizer(num_words=max_num_words)
tokenizer.fit_on_texts(df.x)
x_train=tokenizer.texts_to_sequences(x_train)
x_test=tokenizer.texts_to_sequences(x_test)

# %%
x_train=pad_sequences(x_train,maxlen=seq_len)
x_test=pad_sequences(x_test,maxlen=seq_len)

model=Sequential()
model.add(Embedding(input_dim=max_num_words,
                   input_length=seq_len,
                   output_dim=embedding_size))

# %%
model.add(SimpleRNN(128))
#model.add(Dropout(0.2))
model.add(Dense(3,activation='softmax'))

from tensorflow.keras.optimizers import Adam
adam=Adam(learning_rate=.001)
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:black; background-color:#dfa8e4; font-size: 16px; border-width: 2px; font-weight: bold;" data-toggle="popover">
#     <span style="font-size: 20px;">Fit The Model</span>
# </a>

# %%
model.fit(x_train,y_train,epochs=3,batch_size=32,validation_split=.2)
# Out:
# Epoch 1/3
# WARNING:tensorflow:From C:\Users\Vijay\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Vijay\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 152/152 [==============================] - 5s 22ms/step - loss: 0.5274 - accuracy: 0.7915 - val_loss: 0.0866 - val_accuracy: 0.9901
# Epoch 2/3
# 152/152 [==============================] - 3s 20ms/step - loss: 0.0450 - accuracy: 0.9855 - val_loss: 0.0399 - val_accuracy: 0.9917
# Epoch 3/3
# 152/152 [==============================] - 3s 20ms/step - loss: 0.0412 - accuracy: 0.9860 - val_loss: 0.0401 - val_accuracy: 0.9851

# %%
pred_prob=model.predict(x_test)
# Out:
# 48/48 [==============================] - 1s 6ms/step

# %%
pred=pred_prob.argmax(axis=1)

# %%
y_test=y_test.argmax(axis=1)

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[543,  17,   0],
#        [  8, 495,   0],
#        [  0,   5, 446]], dtype=int64)

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       560
#            1       0.96      0.98      0.97       503
#            2       1.00      0.99      0.99       451
#
#     accuracy                           0.98      1514
#    macro avg       0.98      0.98      0.98      1514
# weighted avg       0.98      0.98      0.98      1514

# %%
accuracy_score(y_test,pred)
# Out:
# 0.9801849405548216

# %% [markdown]
# ## <p style="background-color:#B61151; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">LSTM  <p>
#
# ### "LSTM networks are a type of recurrent neural network (RNN) architecture designed to address the vanishing gradient problem and capture long-term dependencies in sequential data. They achieve this by introducing specialized memory cells with gating mechanisms, allowing them to selectively retain and update information over multiple time steps. This enables LSTMs to effectively model complex sequential patterns, making themwell-suited for tasks such as speech recognition, language translation, and time series forecasting."

# %%
pd.read_csv(r"D:\Medical.csv",encoding='latin-1')
# Out:
#       Unnamed: 0               0  \
# 0              0  Thyroid_Cancer
# 1              1  Thyroid_Cancer
# 2              2  Thyroid_Cancer
# 3              3  Thyroid_Cancer
# 4              4  Thyroid_Cancer
# ...          ...             ...
# 7565        7565    Colon_Cancer
# 7566        7566    Colon_Cancer
# 7567        7567    Colon_Cancer
# 7568        7568    Colon_Cancer
# 7569        7569    Colon_Cancer
#
#                                                       a
# 0     Thyroid surgery in  children in a single insti...
# 1     " The adopted strategy was the same as that us...
# 2     coronary arterybypass grafting thrombosis ï¬b...
# 3      Solitary plasmacytoma SP of the skull is an u...
# 4      This study aimed to investigate serum matrix ...
# ...                                                 ...
# 7565  we report the case of a 24yearold man who pres...
# 7566  among synchronous colorectal cancers scrcs rep...
# 7567  the heterogeneity of cancer cells is generally...
# 7568  "adipogenesis is the process through which mes...
# 7569  the periparturient period is one of the most c...
#
# [7570 rows x 3 columns]

# %%
med=pd.read_csv(r"D:\Medical.csv",encoding='latin-1')

# %%
df=pd.DataFrame(med['0'])

# %%
df['x']=med['a']

# %%
df.rename(columns={'0':'y'},inplace=True)

# %%
df.y=df.y.replace({'Thyroid_Cancer':0,'Colon_Cancer':1,'Lung_Cancer':2})

# %%
df.head()
# Out:
#    y                                                  x
# 0  0  Thyroid surgery in  children in a single insti...
# 1  0  " The adopted strategy was the same as that us...
# 2  0  coronary arterybypass grafting thrombosis ï¬b...
# 3  0   Solitary plasmacytoma SP of the skull is an u...
# 4  0   This study aimed to investigate serum matrix ...

# %%
df.y.nunique()
# Out:
# 3

# %%
df.isnull().sum()[df.isnull().sum()>0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:black; background-color:#dfa8e4; font-size: 16px; border-width: 2px; font-weight: bold;" data-toggle="popover">
#     <span style="font-size: 20px;">Spliting Data into Train and Test</span>
# </a>

# %%
df_x=df.iloc[:,1]
df_y=df.iloc[:,0]
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(df_x,df_y,test_size=.2)

# %%
from tensorflow.keras.utils import to_categorical

# Assuming y_train and y_test are your class labels
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
max_num_words=8000 #from entire corpus sleect 10000 words
seq_len=100 # how many words out of 10000 you wish to take from each document
embedding_size=100 #vector length of each word

# %% [markdown]
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:black; background-color:#dfa8e4; font-size: 16px; border-width: 2px; font-weight: bold;" data-toggle="popover">
#     <span style="font-size: 20px;">Sampling</span>
# </a>

# %%
tokenizer=Tokenizer(num_words=max_num_words)
tokenizer.fit_on_texts(df.x)
x_train=tokenizer.texts_to_sequences(x_train)
x_test=tokenizer.texts_to_sequences(x_test)

# %%
x_train=pad_sequences(x_train,maxlen=seq_len)
x_test=pad_sequences(x_test,maxlen=seq_len)

model=Sequential()
model.add(Embedding(input_dim=max_num_words,
                   input_length=seq_len,
                   output_dim=embedding_size))

# %%
model.add(LSTM(128))
model.add(Dropout(0.2))
model.add(Dense(3,activation='softmax'))

from tensorflow.keras.optimizers import Adam
adam=Adam(learning_rate=.001)
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:black; background-color:#dfa8e4; font-size: 16px; border-width: 2px; font-weight: bold;" data-toggle="popover">
#     <span style="font-size: 20px;">Fit The Model</span>
# </a>

# %%
model.fit(x_train,y_train,epochs=8,batch_size=32,validation_split=.2)
# Out:
# Epoch 1/8
# 152/152 [==============================] - 10s 51ms/step - loss: 0.6075 - accuracy: 0.7120 - val_loss: 0.1428 - val_accuracy: 0.9604
# Epoch 2/8
# 152/152 [==============================] - 8s 49ms/step - loss: 0.0954 - accuracy: 0.9661 - val_loss: 0.0816 - val_accuracy: 0.9695
# Epoch 3/8
# 152/152 [==============================] - 7s 48ms/step - loss: 0.0590 - accuracy: 0.9752 - val_loss: 0.0388 - val_accuracy: 0.9827
# Epoch 4/8
# 152/152 [==============================] - 7s 47ms/step - loss: 0.0469 - accuracy: 0.9773 - val_loss: 0.0389 - val_accuracy: 0.9794
# Epoch 5/8
# 152/152 [==============================] - 7s 48ms/step - loss: 0.0375 - accuracy: 0.9814 - val_loss: 0.0272 - val_accuracy: 0.9843
# Epoch 6/8
# 152/152 [==============================] - 8s 53ms/step - loss: 0.0329 - accuracy: 0.9800 - val_loss: 0.0373 - val_accuracy: 0.9794
# Epoch 7/8
# 152/152 [==============================] - 7s 48ms/step - loss: 0.0330 - accuracy: 0.9841 - val_loss: 0.0280 - val_accuracy: 0.9860
# Epoch 8/8
# 152/152 [==============================] - 7s 48ms/step - loss: 0.0340 - accuracy: 0.9825 - val_loss: 0.0863 - val_accuracy: 0.9711

# %%
pred_prob=model.predict(x_test)
# Out:
# 48/48 [==============================] - 1s 16ms/step

# %%
pred=pred_prob.argmax(axis=1)

# %%
y_test=y_test.argmax(axis=1)

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[534,  10,   0],
#        [ 19, 530,   0],
#        [ 11,   0, 410]], dtype=int64)

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96       544
#            1       0.98      0.97      0.97       549
#            2       1.00      0.97      0.99       421
#
#     accuracy                           0.97      1514
#    macro avg       0.98      0.97      0.97      1514
# weighted avg       0.97      0.97      0.97      1514

# %%
accuracy_score(y_test,pred)
# Out:
# 0.9735799207397622

# %% [markdown]
# ## <p style="background-color:#B61151; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Bidirection LSTM  <p>
# ### BiLSTM networks extend the capabilities of traditional LSTMs by processing input sequences in both forward and backward directions. This allows them to capture context from past and future inputs simultaneously, enhancing their ability to understand and model complex dependencies in sequential data. BiLSTMs areparticularly effective for tasks such as sequence labeling, sentiment analysis, and machine translation, where bidirectional context is crucial for accurate prediction."

# %%
pd.read_csv(r"D:\Medical.csv",encoding='latin-1')
# Out:
#       Unnamed: 0               0  \
# 0              0  Thyroid_Cancer
# 1              1  Thyroid_Cancer
# 2              2  Thyroid_Cancer
# 3              3  Thyroid_Cancer
# 4              4  Thyroid_Cancer
# ...          ...             ...
# 7565        7565    Colon_Cancer
# 7566        7566    Colon_Cancer
# 7567        7567    Colon_Cancer
# 7568        7568    Colon_Cancer
# 7569        7569    Colon_Cancer
#
#                                                       a
# 0     Thyroid surgery in  children in a single insti...
# 1     " The adopted strategy was the same as that us...
# 2     coronary arterybypass grafting thrombosis ï¬b...
# 3      Solitary plasmacytoma SP of the skull is an u...
# 4      This study aimed to investigate serum matrix ...
# ...                                                 ...
# 7565  we report the case of a 24yearold man who pres...
# 7566  among synchronous colorectal cancers scrcs rep...
# 7567  the heterogeneity of cancer cells is generally...
# 7568  "adipogenesis is the process through which mes...
# 7569  the periparturient period is one of the most c...
#
# [7570 rows x 3 columns]

# %%
med=pd.read_csv(r"D:\Medical.csv",encoding='latin-1')

# %%
med=med.loc[:,['0','a']]

# %%
med=med.rename(columns={'0':'y','a':'x'})

# %%
med=med.replace({'Thyroid_Cancer':0,'Colon_Cancer':1,'Lung_Cancer':2})
med.head()
# Out:
#    y                                                  x
# 0  0  Thyroid surgery in  children in a single insti...
# 1  0  " The adopted strategy was the same as that us...
# 2  0  coronary arterybypass grafting thrombosis ï¬b...
# 3  0   Solitary plasmacytoma SP of the skull is an u...
# 4  0   This study aimed to investigate serum matrix ...

# %% [markdown]
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:black; background-color:#dfa8e4; font-size: 16px; border-width: 2px; font-weight: bold;" data-toggle="popover">
#     <span style="font-size: 20px;">Spliting Data into Train and Test</span>
# </a>

# %%
med_x =  med.iloc[:,1]
med_y = med.iloc[:,0]
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(med_x, med_y, test_size=.2)

# %%
y_train = to_categorical(y_train) # one hot endcoding

# %%
max_num_words = 8000      # from the entire corpus select 10000 words
seq_len = 100               # how many words out of 10000 you wish to take from each document
embeddings_size = 100      # vector length of each word

# %% [markdown]
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:black; background-color:#dfa8e4; font-size: 16px; border-width: 2px; font-weight: bold;" data-toggle="popover">
#     <span style="font-size: 20px;">Sampling</span>
# </a>

# %%
tokenizer = Tokenizer(num_words = max_num_words)# word to num
tokenizer.fit_on_texts(med.x)
x_train = tokenizer.texts_to_sequences(x_train)

x_test = tokenizer.texts_to_sequences(x_test)

x_train = pad_sequences(x_train, maxlen=seq_len)


x_test = pad_sequences(x_test, maxlen=seq_len)

# %%
model = Sequential() # initialize the network
model.add(Embedding(input_dim= max_num_words,
                   input_length= seq_len,
                   output_dim = embeddings_size))

# %%
model.add(Bidirectional(LSTM(65)))
model.add(Dropout(0.2))
model.add(Dense(3, activation='softmax'))# Dense 3

# %%
from tensorflow.keras.optimizers import Adam
adam = Adam(learning_rate = .001)
model.compile(optimizer='adam', loss ='categorical_crossentropy', metrics =['accuracy'])

# %% [markdown]
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:black; background-color:#dfa8e4; font-size: 16px; border-width: 2px; font-weight: bold;" data-toggle="popover">
#     <span style="font-size: 20px;">Fit The Model</span>
# </a>

# %%
model.fit(x_train, y_train, epochs = 5, batch_size = 32, validation_split=.2)
# Out:
# Epoch 1/5
# 152/152 [==============================] - 11s 43ms/step - loss: 0.6292 - accuracy: 0.7112 - val_loss: 0.7630 - val_accuracy: 0.8342
# Epoch 2/5
# 152/152 [==============================] - 6s 36ms/step - loss: 0.3172 - accuracy: 0.8865 - val_loss: 0.1298 - val_accuracy: 0.9587
# Epoch 3/5
# 152/152 [==============================] - 6s 39ms/step - loss: 0.0729 - accuracy: 0.9748 - val_loss: 0.0618 - val_accuracy: 0.9794
# Epoch 4/5
# 152/152 [==============================] - 6s 38ms/step - loss: 0.0471 - accuracy: 0.9814 - val_loss: 0.0286 - val_accuracy: 0.9860
# Epoch 5/5
# 152/152 [==============================] - 6s 38ms/step - loss: 0.0345 - accuracy: 0.9870 - val_loss: 0.0258 - val_accuracy: 0.9860

# %%
pred=model.predict(x_test)
pred
# Out:
# 48/48 [==============================] - 1s 10ms/step
# array([[3.3801617e-03, 1.4318597e-03, 9.9518800e-01],
#        [4.7070929e-03, 9.9464780e-01, 6.4512371e-04],
#        [9.9942088e-01, 2.9579541e-04, 2.8329575e-04],
#        ...,
#        [5.8137590e-01, 4.1453835e-01, 4.0857061e-03],
#        [3.4344257e-03, 9.9620289e-01, 3.6265343e-04],
#        [2.9773857e-03, 8.4634358e-04, 9.9617624e-01]], dtype=float32)

# %%
pred_classes=pred.argmax(axis=1)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
tab=confusion_matrix(y_test,pred_classes)
tab
# Out:
# array([[579,  10,   0],
#        [ 10, 488,   0],
#        [  0,   0, 427]], dtype=int64)

# %%
accuracy_score(y_test,pred_classes)
# Out:
# 0.9867899603698811

# %% [markdown]
# # Compression of Models

# %%
l1=('Naive Bayes ','RNN','LSTM','Bidirection LSTM')
l2=(92.73,96.43,98.41,98.48)

importances=pd.DataFrame()
importances['Models']=l1
importances['Accuracy']=l2

importances
# Out:
#              Models  Accuracy
# 0      Naive Bayes      92.73
# 1               RNN     96.43
# 2              LSTM     98.41
# 3  Bidirection LSTM     98.48

# %% [markdown]
# # CONCLUSION
# - **Analyzing and classifying these types of text data can provide valuable insights for
# healthcare professionals, researchers, and patients, facilitating better understanding, diagnosis,
# treatment, and management of cancer
# -->Thyroid_Cancer,Colon_Cancer,Lung_Cance**

# %% [markdown]
# <p style="background-color:purple; font-family:newtimeroman; color:#FFF9ED; font-size:200%; text-align:center; border-radius:20px; padding:20px;"><strong>Thank You :)</strong></p>
